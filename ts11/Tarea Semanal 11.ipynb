# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 11
#
# *Roman Ordoñez*

# %% [markdown]
# A continuacion dejo la resolucion de la Tarea Semanal 11. Desde ya pido disculpas por la indefendible demora en la entrega. Estoy a dispocion de cualquier consulta o respuesta que deseen dar

# %% [markdown]
# <img src="./ts11_1.jpg" width="500" />

# %% [markdown]
# <img src="./ts11_2.jpg" width="500" />

# %% [markdown]
# <img src="./ts11_3.jpg" width="500" />

# %% [markdown]
# <img src="./ts11_4.jpg" width="500" />

# %% [markdown]
# <img src="./ts11_5.jpg" width="500" />
