# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 10
#
# *Roman Ordoñez*

# %% [markdown]
# <img src="./ts10_1.jpg" width="500" />

# %% [markdown]
# <img src="./ts10_2.jpg" width="500" />

# %% [markdown]
# <img src="./ts10_3.jpg" width="500" />

# %% [markdown]
# <img src="./ts10_4.jpg" width="500" />
