# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 7
#
# *Roman Ordoñez*

# %% [markdown]
# ### Consignas
# 1. Construir la **Matriz Admitancia Indefinida** para cada caso. En el **BS170** plantear el modelo lineal visto en clase con admitancias y generadores de corriente, que tenga en cuenta: $C_{iss}$, $C_{oss}$, $C_{rss}$ y $gm$
# 2. Para la red T se pide: <br>
#     a) Obtener $\frac{V_{23}}{V_{13}}$; $\frac{V_{21}}{V_{31}}$ y $\frac{V_{12}}{V_{32}}$, explicitando el armado de los cofactores de segundo orden <br>
#     b) Graficar y observar detenidamente la respuesta de modulo y fase para cada transferencia. Analizar si entre 2 de las trasferencias halladas se cumple que son complementarias en modulo: $|T_a + T_b| = 1$
# 3. Para el MOS se pide:<br>
#     a) Dada la MAI hallada en 1 obtener los parametros *Y* para las configuraciones *source comun* y *drain comun*<br>
#     b) Calulcar la matriz de parametros *ABCD* en configuracion sourcen comun

# %% [markdown]
# ### Punto 1

# %% [markdown]
# <img src="TS7_1.jpg" width="500">

# %% [markdown]
# Para la obtencion de la matriz de la red Tee, se añadio un nodo interno (Nodo 4) en la union de los 3 componentes.

# %% [markdown]
# ### Punto 2

# %% [markdown]
# <img src="TS7_2.jpg" width="500">

# %% [markdown]
# <img src="TS7_3.jpg" width="500">

# %% [markdown]
# Sobre el punto b, donde se busca que la suma de los modulos de las transferencias halladas sea 1, no pude llegar al resultado pedido es por eso que no se encuentra realizado. Revise los calculos de las transferencias, mas que nada en el calculo de los cofactores pero no encuentro el error que me impide llegar al valor deseado.

# %% [markdown]
# ### Punto 3

# %% [markdown]
# <img src="TS7_4.jpg" width="500">

# %% [markdown]
# Para obtener las matrices *Y* partiendo de la MAI, lo que realice fue la supresion de la fila y la columan representante del source o del drain respectivamente, logrando asi una matriz de 2x2
