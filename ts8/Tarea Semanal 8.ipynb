# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 8
#
# *Roman Ordoñez*

# %% [markdown]
# ## Punto 1

# %% [markdown]
# <img src="ts8_1.jpg" width="500">

# %% [markdown]
# <img src="ts8_2.jpg" width="500">

# %% [markdown]
# ## Punto 2

# %% [markdown]
# <img src="ts8_3.jpg" width="500">

# %% [markdown]
# ## Punto 3 y 4

# %% [markdown]
# <img src="ts8_4.jpg" width="500">

# %% [markdown]
# ## Punto 5

# %% [markdown]
# <img src="ts8_5.jpg" width="500">
